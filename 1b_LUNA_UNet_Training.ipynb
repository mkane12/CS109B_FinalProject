# %% [markdown]
# # 2D UNet

# %% [markdown]
# ## Environment Setup

# %%
import time
import random 
import requests
import numpy as np
import pandas as pd

import keras
from keras.models import Model, load_model
from keras.layers import Input, UpSampling2D, SpatialDropout2D
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.layers.normalization import BatchNormalization
from keras.callbacks import ModelCheckpoint
from keras.optimizers import Adam
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from skimage.transform import resize

import tensorflow as tf

import matplotlib.pyplot as plt
# %matplotlib inline

""" Settings for visuals"""
alpha = 0.75
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Gather Data

# %%
# File names to save training data
X_train_path = 'X_train.npy'
Y_train_path = 'Y_train.npy'

# %%
# Download training data from S3 bucket
# NOTE: You should only need to run this once. 
s3_url = 'https://s3.amazonaws.com/com.bsethwalker/cs109b/luna16/2d/'

r = requests.get(s3_url+X_train_path, allow_redirects=True)
open(X_train_path, 'wb').write(r.content)

r = requests.get(s3_url+Y_train_path, allow_redirects=True)
open(Y_train_path, 'wb').write(r.content);

# %%
# Load full training set
X_train_full = np.load(X_train_path)
Y_train_full = np.load(Y_train_path)

# %% [markdown]
# #### Resize the images

# %%
# Images Dimensions
IMG_WIDTH = 256
IMG_HEIGHT = 256
IMG_CHANNELS = 1 # grayscale would be 1, 3 is RGB

# %%
# Resize the images to the defined sizes
X_train_resized = []
Y_train_resized = []

# Preprocess Images
for i in range(len(X_train_full)):
    X_train_resized.append(resize(X_train_full[i], 
                                  (IMG_WIDTH, IMG_HEIGHT),
                                  mode = 'constant', 
                                  preserve_range = True))
    
    Y_train_resized.append(resize(Y_train_full[i], 
                                  (IMG_WIDTH, IMG_HEIGHT),
                                  mode = 'constant', 
                                  preserve_range = True))

# %%
# Convert to numpy arrays 
X_train_full = np.array(X_train_resized)
Y_train_full = np.array(Y_train_resized)

# Free some memory
del X_train_resized, Y_train_resized

# %%
# Just make sure we have everything, and it's all the 
# expected number of dimensions.
print(len(X_train_full))  # = 888
print(X_train_full.shape) # = (888, 256, 256)
print(Y_train_full.shape) # = (888, 256, 256)
# Out:
# 888
# (888, 256, 256)
# (888, 256, 256)

# %% [markdown]
# ## Create Test and Training Data

# %% [markdown]
# #### Split into Test and Validation

# %%
# Split our training data into test/validation
VAL_SIZE = 75  # Size of validation set

N = X_train_full.shape[0]

# set seed for reproducible split
np.random.seed(42)

msk = np.random.choice(range(N), VAL_SIZE, replace = False)

X_train = X_train_full[[i for i in range(N) if i not in msk]]
Y_train = Y_train_full[[i for i in range(N) if i not in msk]]

X_val = X_train_full[msk]
Y_val = Y_train_full[msk]

print("There are %d training and %d valdiation records out of %d total." 
      % (X_train.shape[0], X_val.shape[0], N))
# Out:
# There are 813 training and 75 valdiation records out of 888 total.

# %%
# Free up memory
del X_train_full, Y_train_full

# %%
# Use expand_dims to add the channel dimension
X_train = np.expand_dims(X_train, axis=3)
Y_train = np.expand_dims(Y_train, axis=3)

X_val = np.expand_dims(X_val, axis=3)
Y_val = np.expand_dims(Y_val, axis=3)

# %%
# Make sure things are the correct dimensions.
print(Y_val.shape)   # = (75, 256, 256, 1)
print(X_train.shape) # = (813, 256, 256, 1)
# Out:
# (75, 256, 256, 1)
# (813, 256, 256, 1)

# %%
# Take a look at an image and it's corresponding mask, 
# just for a sanity check. 
idx = 0

plt.imshow(np.squeeze(X_train[idx]));

# %%
plt.imshow(np.squeeze(Y_train[idx]));

# %% [markdown]
# ## Define Model

# %% [markdown]
# ### Model Hyper-Parameters

# %%
theta = { 'batch_size'     : 24
         ,'epochs'         : 100
         
         ,'dropout_rate'  : 0.5 
         
         ,'filter_cnt'     : 32
         ,'activation'     :'relu'
         ,'padding'        :'same'
         ,'out_activation' :'sigmoid'
         ,'learning_rate'  :1e-5}

# %% [markdown]
# ### Model Definition

# %%
def dice_coef(y_true, y_pred, smooth=1.0):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef_loss(y_true, y_pred):
    
    return -dice_coef(y_true, y_pred)

# %%
def UNET(theta):
    inputs = Input((IMG_WIDTH, IMG_HEIGHT, IMG_CHANNELS))
    
    norm = Lambda(lambda x: x+1024 / (3071+1024))(inputs) # Normalize to [0,1]
    
    conv1 = Conv2D(theta['filter_cnt'], (3, 3), 
                   activation=theta['activation'], 
                   padding=theta['padding'])(norm)
    conv1 = BatchNormalization(axis = 1)(conv1)
    conv1 = Conv2D(theta['filter_cnt'], (3, 3), 
                   activation='relu', 
                   padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(theta['filter_cnt']*2, (3, 3), 
                   activation=theta['activation'], 
                   padding=theta['padding'])(pool1)
    conv2 = BatchNormalization(axis = 1)(conv2)
    conv2 = Conv2D(theta['filter_cnt']*2, (3, 3), 
                   activation=theta['activation'], 
                   padding=theta['padding'])(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(theta['filter_cnt']*4, (3, 3), 
                   activation=theta['activation'], 
                   padding=theta['padding'])(pool2)
    conv3 = BatchNormalization(axis = 1)(conv3)
    conv3 = Conv2D(theta['filter_cnt']*4, (3, 3), 
                   activation=theta['activation'], 
                   padding=theta['padding'])(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(theta['filter_cnt']*8, (3, 3), 
                   activation=theta['activation'], 
                   padding=theta['padding'])(pool3)
    conv4 = BatchNormalization(axis = 1)(conv4)
    conv4 = Conv2D(theta['filter_cnt']*8, (3, 3), 
                   activation=theta['activation'], 
                   padding=theta['padding'])(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(theta['filter_cnt']*16, (3, 3), 
                   activation=theta['activation'], 
                   padding=theta['padding'])(pool4)
    conv5 = BatchNormalization(axis = 1)(conv5)
    conv5 = Conv2D(theta['filter_cnt']*16, (3, 3), 
                   activation=theta['activation'], 
                   padding=theta['padding'])(conv5)

    up6 = UpSampling2D(size=(2, 2))(conv5)
    up6 = concatenate([up6, conv4])
    conv6 = SpatialDropout2D(theta['dropout_rate'])(up6)
    conv6 = Conv2D(theta['filter_cnt']*8, (3, 3), 
                   activation=theta['activation'], 
                   padding=theta['padding'])(conv6)
    conv6 = Conv2D(theta['filter_cnt']*8, (3, 3), 
                   activation=theta['activation'], 
                   padding=theta['padding'])(conv6)

    up7 = UpSampling2D(size=(2, 2))(conv6)
    up7 = concatenate([up7, conv3])
    conv7 = SpatialDropout2D(theta['dropout_rate'])(up7)
    conv7 = Conv2D(theta['filter_cnt']*4, (3, 3), 
                   activation=theta['activation'], 
                   padding=theta['padding'])(conv7)
    conv7 = Conv2D(theta['filter_cnt']*4, (3, 3), 
                   activation=theta['activation'], 
                   padding=theta['padding'])(conv7)

    up8 = UpSampling2D(size=(2, 2))(conv7)
    up8 = concatenate([up8, conv2])
    conv8 = SpatialDropout2D(theta['dropout_rate'])(up8)
    conv8 = Conv2D(theta['filter_cnt']*2, (3, 3), 
                   activation=theta['activation'], 
                   padding=theta['padding'])(conv8)
    conv8 = Conv2D(theta['filter_cnt']*2, (3, 3), 
                   activation=theta['activation'], 
                   padding=theta['padding'])(conv8)

    up9 = UpSampling2D(size=(2, 2))(conv8)
    up9 = concatenate([up9, conv1])
    conv9 = SpatialDropout2D(theta['dropout_rate'])(up9)
    conv9 = Conv2D(theta['filter_cnt'], (3, 3), 
                   activation=theta['activation'], 
                   padding=theta['padding'])(conv9)
    conv9 = Conv2D(theta['filter_cnt'], (3, 3), 
                   activation=theta['activation'], 
                   padding=theta['padding'])(conv9)
    conv10 = Conv2D(1, (1, 1), 
                    activation=theta['out_activation'])(conv9)

    model = Model(inputs=inputs, outputs=conv10)
    
    model.compile(optimizer=Adam(lr=theta['learning_rate']), 
                  loss=dice_coef_loss, 
                  metrics=[dice_coef])
    
    return model

# %%
model = None #'unet2.h5' # Set to None for new model

if model:
    model = load_model(model, 
                       custom_objects={'dice_coef_loss': dice_coef_loss, 
                                       'dice_coef':      dice_coef})
else:
    model = UNET(theta)

# %%
from keras.utils.vis_utils import plot_model

# %%
plot_model(model,'unet.png')

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 256, 256, 1)  0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 256, 256, 1)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 32) 320         lambda_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 256, 256, 32) 1024        conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 256, 256, 32) 9248        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 32) 0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 64) 18496       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128, 128, 64) 512         conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 128, 128, 64) 36928       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 64)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 128)  73856       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64, 64, 128)  256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 64, 64, 128)  147584      batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 128)  0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 256)  295168      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 256)  128         conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 256)  590080      batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 16, 16, 256)  0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 512)  1180160     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 16, 16, 512)  64          conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 512)  2359808     batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 512)  0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 768)  0           up_sampling2d_1[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_1 (SpatialDro (None, 32, 32, 768)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 256)  1769728     spatial_dropout2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 256)  590080      conv2d_11[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 64, 64, 256)  0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 64, 384)  0           up_sampling2d_2[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_2 (SpatialDro (None, 64, 64, 384)  0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 128)  442496      spatial_dropout2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 128)  147584      conv2d_13[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 128, 128, 128 0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 128, 192 0           up_sampling2d_3[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_3 (SpatialDro (None, 128, 128, 192 0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 128, 128, 64) 110656      spatial_dropout2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 128, 128, 64) 36928       conv2d_15[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 256, 256, 64) 0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 256, 256, 96) 0           up_sampling2d_4[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_4 (SpatialDro (None, 256, 256, 96) 0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 256, 256, 32) 27680       spatial_dropout2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 256, 256, 32) 9248        conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 256, 256, 1)  33          conv2d_18[0][0]
# ==================================================================================================
# Total params: 7,848,065
# Trainable params: 7,847,073
# Non-trainable params: 992
# __________________________________________________________________________________________________

# %%
from keras.optimizers import SGD

# %%
'''
NOTE: It takes about 1 hour to train 100 epochs, 
while running on Jupyter Hub. '''

# Track when training starts.
start = time.time()

checkpoint = keras.callbacks.ModelCheckpoint('unet_training.h5', monitor='val_dice_coef', verbose=0, save_best_only=True,
                                save_weights_only=False, mode='auto', period=1)

lr_scheduler = keras.callbacks.ReduceLROnPlateau(monitor='val_dice_coef', factor=0.5,
                                                 patience=5, verbose=0, mode='auto',
                                                 cooldown=0, min_lr=0)

model.compile(optimizer=SGD(lr=theta['learning_rate'], momentum=0.5, nesterov=True), loss=dice_coef_loss, metrics=[dice_coef])

history = model.fit(X_train, Y_train, 
          validation_split = 0.2, 
          batch_size = theta['batch_size'], 
          epochs = 50,
          callbacks=[checkpoint, lr_scheduler])

# See how long it took to train the model
done = time.time()
elapsed = done - start
m, s = divmod(elapsed, 60)

print("Training completed in %.d minutes and %d seconds. " % (m, s))

''' Save the model '''
# Set to None or filename. If none, the model won't save.
filename = 'UNet6' #None

if filename:
    model.save(filename+'.h5')
# Out:
# Train on 650 samples, validate on 163 samples
# Epoch 1/50
# 650/650 [==============================] - 28s 43ms/step - loss: -0.5900 - dice_coef: 0.5900 - val_loss: -0.5536 - val_dice_coef: 0.5536
# Epoch 2/50
# 650/650 [==============================] - 26s 41ms/step - loss: -0.5840 - dice_coef: 0.5840 - val_loss: -0.5536 - val_dice_coef: 0.5536
# Epoch 3/50
# 650/650 [==============================] - 26s 41ms/step - loss: -0.5900 - dice_coef: 0.5900 - val_loss: -0.5537 - val_dice_coef: 0.5537
# Epoch 4/50
# 650/650 [==============================] - 27s 41ms/step - loss: -0.5716 - dice_coef: 0.5716 - val_loss: -0.5533 - val_dice_coef: 0.5533
# Epoch 5/50
# 650/650 [==============================] - 27s 41ms/step - loss: -0.5726 - dice_coef: 0.5726 - val_loss: -0.5532 - val_dice_coef: 0.5532
# Epoch 6/50
# 650/650 [==============================] - 26s 41ms/step - loss: -0.5667 - dice_coef: 0.5667 - val_loss: -0.5535 - val_dice_coef: 0.5535
# Epoch 7/50
# 650/650 [==============================] - 27s 41ms/step - loss: -0.5859 - dice_coef: 0.5859 - val_loss: -0.5530 - val_dice_coef: 0.5530
# Epoch 8/50
# 650/650 [==============================] - 27s 41ms/step - loss: -0.5862 - dice_coef: 0.5862 - val_loss: -0.5530 - val_dice_coef: 0.5530
# Epoch 9/50
# 650/650 [==============================] - 27s 41ms/step - loss: -0.5720 - dice_coef: 0.5720 - val_loss: -0.5524 - val_dice_coef: 0.5524
# Epoch 10/50
# 650/650 [==============================] - 26s 41ms/step - loss: -0.5651 - dice_coef: 0.5651 - val_loss: -0.5525 - val_dice_coef: 0.5525
# Epoch 11/50
# 650/650 [==============================] - 26s 41ms/step - loss: -0.5776 - dice_coef: 0.5776 - val_loss: -0.5525 - val_dice_coef: 0.5525
# Epoch 12/50
# 650/650 [==============================] - 26s 41ms/step - loss: -0.5931 - dice_coef: 0.5931 - val_loss: -0.5525 - val_dice_coef: 0.5525
# Epoch 13/50
# 650/650 [==============================] - 26s 40ms/step - loss: -0.5768 - dice_coef: 0.5768 - val_loss: -0.5526 - val_dice_coef: 0.5526
# Epoch 14/50
# 650/650 [==============================] - 26s 40ms/step - loss: -0.5722 - dice_coef: 0.5722 - val_loss: -0.5529 - val_dice_coef: 0.5529
# Epoch 15/50
# 650/650 [==============================] - 27s 41ms/step - loss: -0.5715 - dice_coef: 0.5715 - val_loss: -0.5538 - val_dice_coef: 0.5538
# Epoch 16/50
# 650/650 [==============================] - 26s 41ms/step - loss: -0.5866 - dice_coef: 0.5866 - val_loss: -0.5540 - val_dice_coef: 0.5540
# Epoch 17/50
# 650/650 [==============================] - 26s 41ms/step - loss: -0.5619 - dice_coef: 0.5619 - val_loss: -0.5541 - val_dice_coef: 0.5541
# Epoch 18/50
# 650/650 [==============================] - 26s 41ms/step - loss: -0.5729 - dice_coef: 0.5729 - val_loss: -0.5540 - val_dice_coef: 0.5540
# Epoch 19/50
# 650/650 [==============================] - 26s 40ms/step - loss: -0.5941 - dice_coef: 0.5941 - val_loss: -0.5541 - val_dice_coef: 0.5541
# Epoch 20/50
# 650/650 [==============================] - 26s 41ms/step - loss: -0.5764 - dice_coef: 0.5764 - val_loss: -0.5541 - val_dice_coef: 0.5541
# Epoch 21/50
# 650/650 [==============================] - 26s 40ms/step - loss: -0.5709 - dice_coef: 0.5709 - val_loss: -0.5541 - val_dice_coef: 0.5541
# Epoch 22/50
# 650/650 [==============================] - 26s 41ms/step - loss: -0.6029 - dice_coef: 0.6029 - val_loss: -0.5540 - val_dice_coef: 0.5540
# Epoch 23/50
# 650/650 [==============================] - 26s 40ms/step - loss: -0.5854 - dice_coef: 0.5854 - val_loss: -0.5540 - val_dice_coef: 0.5540
# Epoch 24/50
# 650/650 [==============================] - 26s 41ms/step - loss: -0.5898 - dice_coef: 0.5898 - val_loss: -0.5542 - val_dice_coef: 0.5542
# Epoch 25/50
# 650/650 [==============================] - 26s 40ms/step - loss: -0.5743 - dice_coef: 0.5743 - val_loss: -0.5543 - val_dice_coef: 0.5543
# Epoch 26/50
# 650/650 [==============================] - 26s 41ms/step - loss: -0.5830 - dice_coef: 0.5830 - val_loss: -0.5542 - val_dice_coef: 0.5542
# Epoch 27/50
# 650/650 [==============================] - 26s 41ms/step - loss: -0.5809 - dice_coef: 0.5809 - val_loss: -0.5542 - val_dice_coef: 0.5542
# Epoch 28/50
# 650/650 [==============================] - 26s 41ms/step - loss: -0.6035 - dice_coef: 0.6035 - val_loss: -0.5542 - val_dice_coef: 0.5542
# Epoch 29/50
# 650/650 [==============================] - 26s 41ms/step - loss: -0.5552 - dice_coef: 0.5552 - val_loss: -0.5542 - val_dice_coef: 0.5542
# Epoch 30/50
# 650/650 [==============================] - 26s 41ms/step - loss: -0.5825 - dice_coef: 0.5825 - val_loss: -0.5541 - val_dice_coef: 0.5541
# Epoch 31/50
# 650/650 [==============================] - 26s 41ms/step - loss: -0.5760 - dice_coef: 0.5760 - val_loss: -0.5541 - val_dice_coef: 0.5541
# Epoch 32/50
# 650/650 [==============================] - 26s 41ms/step - loss: -0.5596 - dice_coef: 0.5596 - val_loss: -0.5540 - val_dice_coef: 0.5540
# Epoch 33/50
# 650/650 [==============================] - 26s 41ms/step - loss: -0.5652 - dice_coef: 0.5652 - val_loss: -0.5540 - val_dice_coef: 0.5540
# Epoch 34/50
# 650/650 [==============================] - 26s 41ms/step - loss: -0.5662 - dice_coef: 0.5662 - val_loss: -0.5541 - val_dice_coef: 0.5541
# Epoch 35/50
# 650/650 [==============================] - 26s 41ms/step - loss: -0.5876 - dice_coef: 0.5876 - val_loss: -0.5542 - val_dice_coef: 0.5542
# Epoch 36/50
# 650/650 [==============================] - 26s 41ms/step - loss: -0.5802 - dice_coef: 0.5802 - val_loss: -0.5541 - val_dice_coef: 0.5541
# Epoch 37/50
# 650/650 [==============================] - 26s 41ms/step - loss: -0.6051 - dice_coef: 0.6051 - val_loss: -0.5540 - val_dice_coef: 0.5540
# Epoch 38/50
# 650/650 [==============================] - 26s 40ms/step - loss: -0.5677 - dice_coef: 0.5677 - val_loss: -0.5540 - val_dice_coef: 0.5540
# Epoch 39/50
# 650/650 [==============================] - 26s 40ms/step - loss: -0.5609 - dice_coef: 0.5609 - val_loss: -0.5541 - val_dice_coef: 0.5541
# Epoch 40/50
# 650/650 [==============================] - 26s 40ms/step - loss: -0.6008 - dice_coef: 0.6008 - val_loss: -0.5541 - val_dice_coef: 0.5541
# Epoch 41/50
# 650/650 [==============================] - 26s 40ms/step - loss: -0.5700 - dice_coef: 0.5700 - val_loss: -0.5541 - val_dice_coef: 0.5541
# Epoch 42/50
# 650/650 [==============================] - 26s 40ms/step - loss: -0.5864 - dice_coef: 0.5864 - val_loss: -0.5542 - val_dice_coef: 0.5542
# Epoch 43/50
# 650/650 [==============================] - 26s 40ms/step - loss: -0.5723 - dice_coef: 0.5723 - val_loss: -0.5542 - val_dice_coef: 0.5542
# Epoch 44/50
# 650/650 [==============================] - 26s 40ms/step - loss: -0.5718 - dice_coef: 0.5718 - val_loss: -0.5541 - val_dice_coef: 0.5541
# Epoch 45/50
# 650/650 [==============================] - 26s 40ms/step - loss: -0.5901 - dice_coef: 0.5901 - val_loss: -0.5541 - val_dice_coef: 0.5541
# Epoch 46/50
# 650/650 [==============================] - 26s 40ms/step - loss: -0.5719 - dice_coef: 0.5719 - val_loss: -0.5542 - val_dice_coef: 0.5542
# Epoch 47/50
# 650/650 [==============================] - 26s 40ms/step - loss: -0.5756 - dice_coef: 0.5756 - val_loss: -0.5541 - val_dice_coef: 0.5541
# Epoch 48/50
# 650/650 [==============================] - 26s 40ms/step - loss: -0.5619 - dice_coef: 0.5619 - val_loss: -0.5541 - val_dice_coef: 0.5541
# Epoch 49/50
# 650/650 [==============================] - 26s 40ms/step - loss: -0.5992 - dice_coef: 0.5992 - val_loss: -0.5541 - val_dice_coef: 0.5541
# Epoch 50/50
# 650/650 [==============================] - 26s 40ms/step - loss: -0.5595 - dice_coef: 0.5595 - val_loss: -0.5541 - val_dice_coef: 0.5541
# Training completed in 22 minutes and 2 seconds.

# %%
Y_hat = model.predict(X_val)

# %% [markdown]
# #### Visualize Predictions

# %%
idx = 21

# %%
plt.imshow(np.squeeze(X_val[idx]));

# %%
plt.imshow(np.squeeze(Y_val[21]));

# %%
plt.imshow(np.squeeze(Y_hat[idx]));
