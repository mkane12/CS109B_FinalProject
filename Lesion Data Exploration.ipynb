# %%
import numpy as np
import pandas as pd
import csv
import os
import matplotlib.pyplot as plt
import glob
# %matplotlib inline

# %%
lesion_data = pd.read_csv("data/lesion_im_info.csv")
ax = lesion_data['Pathology'].value_counts().plot(kind='bar', color="#93c4ea")
ax.set_xlabel("Pathology")
ax.set_ylabel("Number of Lesions")
# Out:
# Text(0,0.5,'Number of Lesions')

# %%
# Out:
# Object `plot` not found.
